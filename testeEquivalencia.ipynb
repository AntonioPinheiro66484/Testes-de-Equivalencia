# %%
def testarClasse1(renda):
    if renda >= 0 and renda <= 21453.23:
        return "Classe 1: Isento de taxa - Válido"
    elif renda < 0 or renda > 21453.24:
        return "Classe 1: Isento de taxa - Inválido"
    else:
        return "Renda dentro da classe, mas não se encaixa em nenhum dos casos."

def testarClasse2(renda):
    if renda >= 21453.24 and renda <= 32151.48:
        return "Classe 2: Faixa 1 - Válido"
    elif renda < 21453.24:
        return "Classe 2: Faixa 1 - Antes da faixa - Inválido"
    elif renda > 32151.48:
        return "Classe 2: Faixa 1 - Após da faixa - Inválido"
    else:
        return "Renda dentro da classe, mas não se encaixa em nenhum dos casos."

def testarClasse3(renda):
    if renda >= 32151.49 and renda <= 42869.16:
        return "Classe 3: Faixa 2 - Válido"
    elif renda < 32151.49:
        return "Classe 3: Faixa 2 - Antes da faixa - Inválido"
    elif renda > 42869.16:
        return "Classe 3: Faixa 2 - Após a faixa - Inválido"
    else:
        return "Renda dentro da classe, mas não se encaixa em nenhum dos casos."

def testarClasse4(renda):
    if renda >= 42869.17 and renda <= 53565.72:
        return "Classe 4: Faixa 3 - Válido"
    elif renda < 42869.17:
        return "Classe 4: Faixa 3 - Antes da faixa - Inválido"
    elif renda > 53565.72:
        return "Classe 4: Faixa 3 - Após a faixa - Inválido"
    else:
        return "Renda dentro da classe, mas não se encaixa em nenhum dos casos."

def testarClasse5(renda):
    if renda >= 53565.73:
        return "Classe 5: Faixa 4 - Válido"
    else:
        return "Classe 5: Faixa 4 - Antes da faixa - Inválido"

valoresRenda = [-0.35, 19453.23, 25353.55, 25453.24, 20453.24, 52121.45, 36141.19, 31431.48, 46869.17, 47769.43, 20869.16, 453565.73, 153565.73, 10565.72]

for renda in valoresRenda:
    resultadoClasse1 = testarClasse1(renda)
    resultadoClasse2 = testarClasse2(renda)
    resultadoClasse3 = testarClasse3(renda)
    resultadoClasse4 = testarClasse4(renda)
    resultadoClasse5 = testarClasse5(renda)

    print(f"Renda: R$ {renda:.2f}")
    print(f"Classe 1: {resultadoClasse1}")
    print(f"Classe 2: {resultadoClasse2}")
    print(f"Classe 3: {resultadoClasse3}")
    print(f"Classe 4: {resultadoClasse4}")
    print(f"Classe 5: {resultadoClasse5}")
    print("\n")
